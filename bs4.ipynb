# %%
import requests as rq
from bs4 import BeautifulSoup

# %%
url = 'https://quotes.toscrape.com/'
resp = rq.get(url)
resp
# Out:
# <Response [200]>

# %%
resp.content
# Out:
# b'<!DOCTYPE html>\n<html lang="en">\n<head>\n\t<meta charset="UTF-8">\n\t<title>Quotes to Scrape</title>\n    <link rel="stylesheet" href="/static/bootstrap.min.css">\n    <link rel="stylesheet" href="/static/main.css">\n</head>\n<body>\n    <div class="container">\n        <div class="row header-box">\n            <div class="col-md-8">\n                <h1>\n                    <a href="/" style="text-decoration: none">Quotes to Scrape</a>\n                </h1>\n            </div>\n            <div class="col-md-4">\n                <p>\n                \n                    <a href="/login">Login</a>\n                \n                </p>\n            </div>\n        </div>\n    \n\n<div class="row">\n    <div class="col-md-8">\n\n    <div class="quote" itemscope itemtype="http://schema.org/CreativeWork">\n        <span class="text" itemprop="text">\xe2\x80\x9cThe world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.\xe2\x8
# ...

# %%
bSoup = BeautifulSoup(resp.content , 'html.parser')
bSoup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Quotes to Scrape</title>
# <link href="/static/bootstrap.min.css" rel="stylesheet"/>
# <link href="/static/main.css" rel="stylesheet"/>
# </head>
# <body>
# <div class="container">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
# ...

# %%
type(bSoup)
# Out:
# bs4.BeautifulSoup

# %%
bSoup.title
# Out:
# <title>Quotes to Scrape</title>

# %%
bSoup.title.text
# Out:
# 'Quotes to Scrape'

# %%
bSoup.h1.text
# Out:
# '\nQuotes to Scrape\n'

# %%
first_div = bSoup.div
first_div
# Out:
# <div class="container">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# <a class="tag" href="/tag/thinking/page/1/">thinking</a>
# ...

# %%
type(first_div)
# Out:
# bs4.element.Tag

# %%
first_div.attrs
# Out:
# {'class': ['container']}

# %%
first_div.div.div.attrs
# Out:
# {'class': ['col-md-8']}

# %%
first_div.div
# Out:
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>

# %%
first_div.div.div.a
# Out:
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>

# %%
first_div.attrs['class'].append(' Hubnex Technologies')

# %%
first_div
# Out:
# <div class="container  Hubnex Technologies">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# ...

# %%
first_div.attrs['myattr'] = 'Hello'

# %%
first_div
# Out:
# <div class="container  Hubnex Technologies" myattr="Hello">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# ...

# %%
bSoup.ul
# Out:
# <ul class="pager">
# <li class="next">
# <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
# </li>
# </ul>

# %%
print(bSoup.ul.prettify())
# Out:
# <ul class="pager">
#  <li class="next">
#   <a href="/page/2/">
#    Next
#    <span aria-hidden="true">
#     →
#    </span>
#   </a>
#  </li>
# </ul>

# %%
ulTag = bSoup.ul
ulTag
# Out:
# <ul class="pager">
# <li class="next">
# <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
# </li>
# </ul>

# %%
ulTag.li
# Out:
# <li class="next">
# <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
# </li>

# %%
bSoup.ul.children

# %%
from bs4.element import NavigableString 




list(ulTag.children)[0]
type(list(ulTag.children)[0])
# Out:
# bs4.element.NavigableString

# %%
list(filter(lambda x : type(x) != NavigableString , ulTag.children))
# Out:
# [<li class="next">
#  <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
#  </li>]

# %%
list(first_div.children)
# Out:
# ['\n',
#  <div class="row header-box">
#  <div class="col-md-8">
#  <h1>
#  <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#  </h1>
#  </div>
#  <div class="col-md-4">
#  <p>
#  <a href="/login">Login</a>
#  </p>
#  </div>
#  </div>,
#  '\n',
#  <div class="row">
#  <div class="col-md-8">
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
#  <span>by <small class="author" itemprop="author">Albert Einstein</small>
#  <a href="/author/Albert-Einstein">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
#  <a class="tag" href="/tag/change/page/1/">change</a>
#  <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# ...

# %%
list(filter(lambda x : type(x) != NavigableString , first_div.children))
# Out:
# [<div class="row header-box">
#  <div class="col-md-8">
#  <h1>
#  <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#  </h1>
#  </div>
#  <div class="col-md-4">
#  <p>
#  <a href="/login">Login</a>
#  </p>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-md-8">
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
#  <span>by <small class="author" itemprop="author">Albert Einstein</small>
#  <a href="/author/Albert-Einstein">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
#  <a class="tag" href="/tag/change/page/1/">change</a>
#  <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
#  <a class="tag" href="/tag/thinking/page/1/">thinking</a>
# ...

# %%
def removeNavStr(ele):
    return list(filter(lambda x : type(x) != NavigableString , ele))

# %%
removeNavStr(first_div.children)
# Out:
# [<div class="row header-box">
#  <div class="col-md-8">
#  <h1>
#  <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#  </h1>
#  </div>
#  <div class="col-md-4">
#  <p>
#  <a href="/login">Login</a>
#  </p>
#  </div>
#  </div>,
#  <div class="row">
#  <div class="col-md-8">
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
#  <span>by <small class="author" itemprop="author">Albert Einstein</small>
#  <a href="/author/Albert-Einstein">(about)</a>
#  </span>
#  <div class="tags">
#              Tags:
#              <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
#  <a class="tag" href="/tag/change/page/1/">change</a>
#  <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
#  <a class="tag" href="/tag/thinking/page/1/">thinking</a>
# ...

# %%
removeNavStr(ulTag.children)
# Out:
# [<li class="next">
#  <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
#  </li>]

# %%
removeNavStr(bSoup.ul.children)
# Out:
# [<li class="next">
#  <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
#  </li>]

# %% [markdown]
# # Descendants

# %%
bSoup.ul.descendants
# Out:
# <generator object Tag.descendants at 0x000001A0CB1CDD20>

# %%
list(bSoup.ul.descendants)
# Out:
# ['\n',
#  <li class="next">
#  <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
#  </li>,
#  '\n',
#  <a href="/page/2/">Next <span aria-hidden="true">→</span></a>,
#  'Next ',
#  <span aria-hidden="true">→</span>,
#  '→',
#  '\n',
#  '\n']

# %%
Desc = removeNavStr(bSoup.ul.descendants)
Desc
# Out:
# [<li class="next">
#  <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
#  </li>,
#  <a href="/page/2/">Next <span aria-hidden="true">→</span></a>,
#  <span aria-hidden="true">→</span>]

# %%
first_divDesc = removeNavStr(first_div.descendants)
first_divDesc
# Out:
# [<div class="row header-box">
#  <div class="col-md-8">
#  <h1>
#  <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#  </h1>
#  </div>
#  <div class="col-md-4">
#  <p>
#  <a href="/login">Login</a>
#  </p>
#  </div>
#  </div>,
#  <div class="col-md-8">
#  <h1>
#  <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#  </h1>
#  </div>,
#  <h1>
#  <a href="/" style="text-decoration: none">Quotes to Scrape</a>
#  </h1>,
#  <a href="/" style="text-decoration: none">Quotes to Scrape</a>,
#  <div class="col-md-4">
#  <p>
#  <a href="/login">Login</a>
#  </p>
#  </div>,
#  <p>
#  <a href="/login">Login</a>
#  </p>,
#  <a href="/login">Login</a>,
#  <div class="row">
#  <div class="col-md-8">
#  <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
#  <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# ...

# %%
first_div
# Out:
# <div class="container  Hubnex Technologies" myattr="Hello">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# ...

# %%
first_divDesc[0].parent
# Out:
# <div class="container  Hubnex Technologies" myattr="Hello">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# ...

# %% [markdown]
# # Sibling

# %%
ulTag
# Out:
# <ul class="pager">
# <li class="next">
# <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
# </li>
# </ul>

# %%
first_div
# Out:
# <div class="container  Hubnex Technologies" myattr="Hello">
# <div class="row header-box">
# <div class="col-md-8">
# <h1>
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>
# </h1>
# </div>
# <div class="col-md-4">
# <p>
# <a href="/login">Login</a>
# </p>
# </div>
# </div>
# <div class="row">
# <div class="col-md-8">
# <div class="quote" itemscope="" itemtype="http://schema.org/CreativeWork">
# <span class="text" itemprop="text">“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”</span>
# <span>by <small class="author" itemprop="author">Albert Einstein</small>
# <a href="/author/Albert-Einstein">(about)</a>
# </span>
# <div class="tags">
#             Tags:
#             <meta class="keywords" content="change,deep-thoughts,thinking,world" itemprop="keywords"/>
# <a class="tag" href="/tag/change/page/1/">change</a>
# <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>
# ...

# %%
first_div.nextSibling
# Out:
# '\n'

# %%
first_div.nextSibling.nextSibling
# Out:
# <footer class="footer">
# <div class="container">
# <p class="text-muted">
#                 Quotes by: <a href="https://www.goodreads.com/quotes">GoodReads.com</a>
# </p>
# <p class="copyright">
#                 Made with <span class="zyte">❤</span> by <a class="zyte" href="https://www.zyte.com">Zyte</a>
# </p>
# </div>
# </footer>

# %%
first_div.nextSibling.nextSibling.nextSibling.nextSibling

# %%
ulTag.nextSibling.previousSibling
# Out:
# <ul class="pager">
# <li class="next">
# <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
# </li>
# </ul>

# %%
bSoup.ul.li.nextSibling
# Out:
# '\n'

# %%
bSoup.ul.li.nextSibling.previousSibling
# Out:
# <li class="next">
# <a href="/page/2/">Next <span aria-hidden="true">→</span></a>
# </li>

# %% [markdown]
# # Extract String

# %%
bSoup.a.text
# Out:
# 'Quotes to Scrape'

# %%
bSoup.a.getText()
# Out:
# 'Quotes to Scrape'

# %%
bSoup.a.string
# Out:
# 'Quotes to Scrape'

# %%
bSoup.ul.text
# Out:
# '\n\nNext →\n\n'

# %%
bSoup.ul.li.getText()
# Out:
# '\nNext →\n'

# %%
bSoup.ul.li.a.getText()
# Out:
# 'Next →'

# %%
bSoup.ul.li.a.string

# %%
ulTag.li.a.getText()
# Out:
# 'Next →'

# %%
print(f'ulTag.li.a.getText() : {ulTag.li.a.getText()}, {type(ulTag.li.a.getText())}')
# Out:
# ulTag.li.a.getText() : Next →, <class 'str'>

# %%
print(f'ulTag.li.a.text : {ulTag.li.a.text}, {type(ulTag.li.a.text)}')
# Out:
# ulTag.li.a.text : Next →, <class 'str'>

# %%
print(f'ulTag.li.a.string : {ulTag.li.a.string}, {type(ulTag.li.a.string)}')
# Out:
# ulTag.li.a.string : None, <class 'NoneType'>

# %%
sep = ulTag.getText(separator= ',')
sep
# Out:
# '\n,\n,Next ,→,\n,\n'

# %%
removeNavStr(sep)
# Out:
# ['\n', ',', '\n', ',', 'N', 'e', 'x', 't', ' ', ',', '→', ',', '\n', ',', '\n']

# %%
ulTag.getText(separator=',', strip=True)
# Out:
# 'Next,→'

# %%
bSoup.stripped_strings
# Out:
# <generator object PageElement.stripped_strings at 0x000001A0CA9DEC20>

# %%
bSoupList = list(bSoup.stripped_strings)
bSoupList
# Out:
# ['Quotes to Scrape',
#  'Quotes to Scrape',
#  'Login',
#  '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”',
#  'by',
#  'Albert Einstein',
#  '(about)',
#  'Tags:',
#  'change',
#  'deep-thoughts',
#  'thinking',
#  'world',
#  '“It is our choices, Harry, that show what we truly are, far more than our abilities.”',
#  'by',
#  'J.K. Rowling',
#  '(about)',
#  'Tags:',
#  'abilities',
#  'choices',
#  '“There are only two ways to live your life. One is as though nothing is a miracle. The other is as though everything is a miracle.”',
#  'by',
#  'Albert Einstein',
#  '(about)',
#  'Tags:',
#  'inspirational',
#  'life',
#  'live',
#  'miracle',
#  'miracles',
#  '“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”',
#  'by',
#  'Jane Austen',
#  '(about)',
#  'Tags:',
#  'aliteracy',
#  'books',
#  'classic',
#  'humor',
# ...

# %%
len(bSoupList)
# Out:
# 102

# %%
print(f'bSoupList = {len(bSoupList)}')
# Out:
# bSoupList = 102

# %%
bSoupString = list(bSoup.strings)
bSoupString
# Out:
# ['\n',
#  '\n',
#  '\n',
#  '\n',
#  'Quotes to Scrape',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  'Quotes to Scrape',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  'Login',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”',
#  '\n',
#  'by ',
#  'Albert Einstein',
#  '\n',
#  '(about)',
#  '\n',
#  '\n',
#  '\n            Tags:\n            ',
#  '\n',
#  'change',
#  '\n',
#  'deep-thoughts',
#  '\n',
#  'thinking',
#  '\n',
#  'world',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
#  '“It is our choices, Harry, that show what we truly are, far more than our abilities.”',
#  '\n',
#  'by ',
#  'J.K. Rowling',
#  '\n',
#  '(about)',
#  '\n',
#  '\n',
#  '\n            Tags:\n            ',
#  '\n',
#  'abilities',
#  '\n',
#  'choices',
#  '\n',
#  '\n',
#  '\n',
#  '\n',
# ...

# %%
len(bSoupString)
print(f'bSoupString = {len(bSoupString)}')
# Out:
# bSoupString = 288

# %%
bSoupList[1:4]
# Out:
# ['Quotes to Scrape',
#  'Login',
#  '“The world as we have created it is a process of our thinking. It cannot be changed without changing our thinking.”']

# %%
bSoupList[1:len(bSoupList):4]
# Out:
# ['Quotes to Scrape',
#  'Albert Einstein',
#  'deep-thoughts',
#  'by',
#  'abilities',
#  'Albert Einstein',
#  'life',
#  '“The person, be it gentleman or lady, who has not pleasure in a good novel, must be intolerably stupid.”',
#  'Tags:',
#  'humor',
#  '(about)',
#  '“Try not to become a man of success. Rather become a man of value.”',
#  'Tags:',
#  '“It is better to be hated for what you are than to be loved for what you are not.”',
#  'Tags:',
#  'by',
#  'edison',
#  "“A woman is like a tea bag; you never know how strong it is until it's in hot water.”",
#  'Tags:',
#  'Steve Martin',
#  'obvious',
#  'Top Ten tags',
#  'humor',
#  'friends',
#  'GoodReads.com',
#  'Zyte']

# %% [markdown]
# # find and find_All

# %%
bSoup.find('a')
# Out:
# <a href="/" style="text-decoration: none">Quotes to Scrape</a>

# %%
bSoup.find_all('a')
# Out:
# [<a href="/" style="text-decoration: none">Quotes to Scrape</a>,
#  <a href="/login">Login</a>,
#  <a href="/author/Albert-Einstein">(about)</a>,
#  <a class="tag" href="/tag/change/page/1/">change</a>,
#  <a class="tag" href="/tag/deep-thoughts/page/1/">deep-thoughts</a>,
#  <a class="tag" href="/tag/thinking/page/1/">thinking</a>,
#  <a class="tag" href="/tag/world/page/1/">world</a>,
#  <a href="/author/J-K-Rowling">(about)</a>,
#  <a class="tag" href="/tag/abilities/page/1/">abilities</a>,
#  <a class="tag" href="/tag/choices/page/1/">choices</a>,
#  <a href="/author/Albert-Einstein">(about)</a>,
#  <a class="tag" href="/tag/inspirational/page/1/">inspirational</a>,
#  <a class="tag" href="/tag/life/page/1/">life</a>,
#  <a class="tag" href="/tag/live/page/1/">live</a>,
#  <a class="tag" href="/tag/miracle/page/1/">miracle</a>,
#  <a class="tag" href="/tag/miracles/page/1/">miracles</a>,
#  <a href="/author/Jane-Austen">(about)</a>,
# ...

# %%
aTag = len(bSoup.find_all('a'))
aTag
# Out:
# 55

# %%
bSoup.find_all('p')
# Out:
# [<p>
#  <a href="/login">Login</a>
#  </p>,
#  <p class="text-muted">
#                  Quotes by: <a href="https://www.goodreads.com/quotes">GoodReads.com</a>
#  </p>,
#  <p class="copyright">
#                  Made with <span class="zyte">❤</span> by <a class="zyte" href="https://www.zyte.com">Zyte</a>
#  </p>]

# %%
pTag = len(bSoup.find_all('p'))
pTag
# Out:
# 3
